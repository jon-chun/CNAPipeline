# %% [markdown]
# # NLP Analysis of Mein Kampf
# ---
#
# In this experiment we use sentiment analysis provided by TextBlob and topic modelling. The following libraries are used:
#
# - NLTK
# - TextBlob
# - Gensim
#
# In the paper, these general purpose technologies are tested against state-of-the-art equivalents
#
# - Watson API
#
# ``https://www.ibm.com/demos/live/natural-language-understanding/self-service/home``
# - Google API
#
# ``https://cloud.google.com/natural-language/``
#
# Sentiment analysis is a technique used to understand the sentiment of a body of text through either scoring of words or classification relative to a reference dataset. TextBlob uses a sentiment analysis algorithm provided by the Computational and Psycholinguistics Research Centre (CLiPS). The method is based on crowdsourcing scores of individual words from which sentiment is derived by averaging word scores in a string. The result is a numerical value between -1.0 to indicate negativity and +1.0 to indicate positivity.
#
# Topic Modelling is a statistical method used to reveal latent themes in a text by grouping terms together in a single topic. For example, the terms, 'patient', 'doctor', 'disease', 'cancer', ad 'health' will represents topic 'healthcare'.
#
# In this notebook, these techniques are applied to Hitler's manifesto, Mein Kampf, as a way to test each of these technologies.
#
# The text we use is from the following website and is reproduced in the repo folder.
#
# ``http://www.hitler.org/writings/Mein_Kampf/``

# %% [markdown]
# ## Discussion of Results
#
# For overall sentiment, Mein Kampf scores consistently higher than I Have a Dream for TextBlob. From these results, there are two statements of particular interest from \emph{Mein Kampf}.
#
# ``A state which in this age of racial poisoning dedicates itself to the care of its best racial elements must some day become lord of the earth``
#
# That this statement yields a positive score of +1, for which there is no higher sentiment, is a somewhat troubling result. Reading this statement in context, Hitler others immigrants by equating immigration to racial poisoning whereby "All great cultures of the past perished only because the originally creative race died out from blood poisoning". He is, therefore, arguing to preserve a state's "racial purity" by tending to its indigenous people he regards as a state's "best racial elements". In other words, he creates a self-other gradient between each by dehumanising immigrants as an in-pure outgroup while elevating the purity of those he presents as his indigenous people - the ingroup audience for whom he writes.
#
# This statement should be seen, therefore, as the essential premise of racism by inciting violence or hate against immigrants, which in this case ultimately led to genocide.
#
# ``Like a swarm of hornets they tackled disturbers at our meetings, regardless of superiority of numbers, however great, indifferent to wounds and bloodshed, inspired with the great idea of blazing a trail for the sacred mission of our movement``
#
# The second of these statements refers to "defensive squads" of men tasked with maintaining order at Nationalist Socialist meetings. Reading this statement in context, Hitler legitimises the violent way in which they maintained order by praising their violent actions, yet yields a score of +0.8. How these numerical values relates to the specific features of hate speech is unclear.
#
# While the results for topic modelling seem to have meaning for each particular text, whether or not each constitute hatefulness is indeterminable. The Gensim results are inconclusive since there does not appear to be definitive terms to detect topics related to hate speech.

# %%
# %%time

### analyse the whole document to extract the topics and sentiment
# https://www.analyticsvidhya.com/blog/2016/08/beginners-guide-to-topic-modeling-in-python/
# https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24

import os
from textblob import TextBlob
from collections import Counter
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
import gensim
import collections
from gensim import corpora
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
Lda = gensim.models.ldamodel.LdaModel

### open file
filepath  = r"C:\Users\Steve\OneDrive - University of Southampton\CulturalViolence\KnowledgeBases\data"

with open(os.path.join(filepath, "MeinKampfv2.txt"), 'r') as text:
    speech_text = text.readlines()

# define common functions
def clean(doc): # text cleaning function
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop]) # remove stopwords
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude) # remove punctuation
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split()) #lemmatize words
    return normalized

def Most_Common(lst, quantity):
    data = Counter(lst)
    return data.most_common(quantity)

# speech pre-processing to a bag-of-words
i = TextBlob(''.join(speech_text))
doc_clean = [clean(doc).split() for doc in speech_text] # clean speech to a bag of words
dictionary = corpora.Dictionary(doc_clean) # Creating the term dictionary for the speech, where every unique term is assigned an index.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean] # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

print('Overall Text Topics: ', end='')
print(ldamodel.print_topics(num_topics=10, num_words=3))
print('-----')

print('Text Overall Sentiment: ', end='')
print(i.sentiment.polarity)
print('-----')

print('Text Common Nouns: ', end='')
print(Most_Common(i.noun_phrases, 15))
print('-----')

flat_list = []

for sublist in doc_clean:
    for item in sublist:
        flat_list.append(item)


print('Speech common words: ', end='')
print(Most_Common(flat_list, 5))
print('-----')

# generate speech summary data

counter = 0
most_pos_para = ''
most_neg_para = ''
pos_paras = []
neg_paras = []
most_pos_score = 0
most_neg_score = 0

for section in speech_text:
    paragraph = TextBlob(section)
    
    if paragraph.sentiment.polarity > most_pos_score and paragraph.sentiment.polarity < 1:
        most_pos_para = paragraph
        most_pos_score = paragraph.sentiment.polarity
    elif paragraph.sentiment.polarity < most_neg_score and paragraph.sentiment.polarity > -1:
        most_neg_para = paragraph
        most_neg_score = paragraph.sentiment.polarity
    elif paragraph.sentiment.polarity == 1:
        pos_paras.append(section)
    elif paragraph.sentiment.polarity == -1:
        neg_paras.append(section)
    
        
print('With a score of ', str(most_pos_score), ', the most positive paragraph less than 1 is:')
print(most_pos_para)
print('-----')
print('With a score of ', str(most_neg_score), ', the most negative paragraph greater than -1 is:')
print(most_neg_para)
print('-----')
print('The paragraphs with a sentiment score of 1 are:')
for i in pos_paras:
    print(i)
print()
print('The paragraphs with a sentiment score of -1 are:')
for i in neg_paras:
    print(i)
print('-----')

# generate paragraph summary data by iterating through each paragraph

for section in speech_text:
    counter += 1
    paragraph = TextBlob(section)
    
    doc_clean = [clean(section).split()] # clean section
    dictionary = corpora.Dictionary(doc_clean) # Creating the term dictionary of each paragraph, where every unique term is assigned an index. 
    
    if len(dictionary) > 0: ## skip over empty paragraphs
        doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean] # Converting paragraph into Document Term Matrix using dictionary prepared above.
        ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
    
    print('Paragraph %d' %counter)
    print('    Paragraph topics: ', end='')
    print(ldamodel.print_topics(num_topics=5, num_words=2))
    print('    Paragraph sentiment: ', end='')
    print(paragraph.sentiment.polarity)
    print('    Paragraph nouns: ', end='')
    print(paragraph.noun_phrases)
    print('    Paragraph common words: ', end='')
    
    for w in doc_clean:
        print(Most_Common(w, 5))
        
    print()
# Out:
# Overall Text Topics: [(0, '0.009*"movement" + 0.009*"one"'), (1, '0.011*"german" + 0.008*"germany"'), (2, '0.016*"state" + 0.011*"must"')]
# -----
# Text Overall Sentiment: 0.0964078892045762
# -----
# Text Common Nouns: [('germany', 162), ('reich', 124), ('france', 91), ('revolution', 66), ('england', 66), ('jew', 55), ('marxist', 54), ('marxism', 52), ('german people', 48), ('europe', 46), ('russia', 44), ('movement', 43), ("people 's state", 38), ('munich', 36), ('germans', 36)]
# -----
# Speech common words: [('state', 577), ('people', 520), ('would', 517), ('must', 458), ('one', 430)]
# -----
# With a score of  0.8 , the most positive paragraph less than 1 is:
# Like a swarm of hornets they tackled disturbers at our meetings, regardless of superiority of numbers, however great, indifferent to wounds and bloodshed, inspired with the great idea of blazing a trail for the sacred mission of our movement.
#
# -----
# With a score of  -0.65 , the most negative paragraph greater than -1 is:
# All in all, the cowardly lack of will-power and the incapacity for making decisions are chiefly results of the erroneous education given us in our youth. The disastrous effects of this are now widespread among us. The crowning examples of that tragic chain of consequences are shown in the lack of civil courage which our leading statesmen display.
#
# -----
# The paragraphs with a sentiment score of 1 are:
# A state which in this age of racial poisoning dedicates itself to the care of its best racial elements must some day become lord of the earth.
#
#
# The paragraphs with a sentiment score of -1 are:
# Times of national collapse are determined by the preponderating influence of the worst elements.
#
# Therefore after the Revolution the bourgeois parties also capitulated to the street in a miserable fashion.
#
# -----
# Paragraph 1
#     Paragraph topics: [(0, '0.057*"thesis" + 0.057*"new"'), (1, '0.034*"people" + 0.034*"1920"'), (2, '0.034*"hall" + 0.034*"munich"')]
#     Paragraph sentiment: 0.28454545454545455
#     Paragraph nouns: ['february', 'great mass meeting', 'new movement', 'banquet', 'hofbräuhaus', 'munich', 'twenty-five theses', 'new party']
#     Paragraph common words: [('new', 2), ('thesis', 2), ('february', 1), ('24th', 1), ('1920', 1)]
#
# Paragraph 2
#     Paragraph topics: [(0, '0.024*"along" + 0.024*"principle"'), (1, '0.024*"reach" + 0.024*"thus"'), (2, '0.041*"new" + 0.041*"force"')]
#     Paragraph sentiment: 0.03712121212121211
#     Paragraph nouns: ['new struggle', 'obsolete ideas', 'pernicious tendencies', 'new force', 'feckless bourgeoisie', 'marxists', 'chariot', 'fate']
#     Paragraph common words: [('new', 2), ('force', 2), ('thus', 1), ('brought', 1), ('knowledge', 1)]
#
# Paragraph 3
#     Paragraph topics: [(0, '0.033*"field" + 0.033*"introducing"'), (1, '0.078*"new" + 0.054*"significance"'), (2, '0.033*"conviction" + 0.033*"awakening"')]
#     Paragraph sentiment: 0.08590909090909091
#     Paragraph nouns: ['new movement', 'public significance', 'necessary pre-requisites', 'gigantic struggle', 'sacrosanct conviction', 'new electoral slogan', 'political field', 'new world view', 'radical significance']
#     Paragraph common words: [('new', 3), ('significance', 2), ('evident', 1), ('movement', 1), ('could', 1)]
#
# Paragraph 4
#     Paragraph topics: [(0, '0.065*"must" + 0.045*"one"'), (1, '0.031*"called" + 0.031*"usual"'), (2, '0.031*"try" + 0.031*"arrayed"')]
#     Paragraph sentiment: -0.19480519480519481
#     Paragraph nouns: ['miserable jumble', 'usual party', 'programme', 'new form', 'programmatic monstrosities', "average bourgeois 'programme committee"]
#     Paragraph common words: [('must', 3), ('one', 2), ('opinion', 2), ('used', 2), ('side', 2)]
#
# Paragraph 5
#     Paragraph topics: [(0, '0.008*"experience" + 0.008*"gradually"'), (1, '0.023*"old" + 0.018*"darling"'), (2, '0.008*"employee" + 0.008*"reconsideration"')]
#     Paragraph sentiment: 0.16223169191919193
#     Paragraph nouns: ['parliamentary government', 'old party wagon', 'new colours', 'such occasions', 'party astrologists', 'horoscope readers', 'old parliamentary hands', 'political schooling', 'ample experience', 'similar situation', 'resorting', 'old prescription', 'broad masses', 'office employees', 'innermost desires', "'malicious slogans", 'great astonishment', 'old parties']
#     Paragraph common words: [('old', 4), ('darling', 3), ('party', 3), ('preoccupation', 2), ('something', 2)]
#
# Paragraph 6
#     Paragraph topics: [(0, '0.125*"draw" + 0.125*"new"'), (1, '0.125*"old" + 0.125*"new"'), (2, '0.125*"committee" + 0.125*"draw"')]
#     Paragraph sentiment: 0.11818181818181818
#     Paragraph nouns: ['old programme']
#     Paragraph common words: [('committee', 1), ('meet', 1), ('revise', 1), ('old', 1), ('programme', 1)]
#
# Paragraph 7
#     Paragraph topics: [(0, '0.010*"hurriedly" + 0.010*"philistine"'), (1, '0.023*"one" + 0.023*"assured"'), (2, '0.010*"demand" + 0.010*"tariff"')]
#     Paragraph sentiment: 0.13977272727272727
#     Paragraph nouns: ['soldier changes', 'war –', 'new programme', 'market prices', 'civil servants', 'widows', 'generous assistance', 'good grounds', 'whole normal host', 'god', 'impenetrable stupidity', "'the reconstruction", 'reich']
#     Paragraph common words: [('one', 3), ('assured', 3), ('change', 2), ('interest', 2), ('abolished', 2)]
#
# Paragraph 8
#     Paragraph topics: [(0, '0.022*"deputy" + 0.022*"attendance"'), (1, '0.013*"wends" + 0.013*"election"'), (2, '0.013*"committee" + 0.013*"leave"')]
#     Paragraph sentiment: -0.007142857142857141
#     Paragraph nouns: ['election day', 'public meeting', 'tasks –', 'programme committee', 'progressive reorganization', 'public affairs', 'parliamentarians means', 'daily remunerations', 'morning', 'honourable deputy wends', 'front hall', 'onerous service', 'small indemnity']
#     Paragraph common words: [('parliamentarian', 2), ('public', 2), ('daily', 2), ('attendance', 2), ('morning', 2)]
#
# Paragraph 9
#     Paragraph topics: [(0, '0.008*"bourgeois" + 0.008*"deceiver"'), (1, '0.008*"leave" + 0.008*"butterfly"'), (2, '0.024*"public" + 0.019*"again"')]
#     Paragraph sentiment: 0.053625541125541125
#     Paragraph nouns: ['critical weeks', 'parliamentary corporations', 'honourable gentlemen', 'irresistible desire', 'parliamentarian worms', 'great house', 'puppets', 'new wings', 'enormous labours', 'malicious obstinacy', 'grateful applause', 'unintelligent masses', 'public ingratitude', 'certain pitch', 'impenetrable stupidity', 'such tactics', 'new programme', 'proletarian herds', 'common stall', 'old deceivers', "'people 's man", 'labour candidate', 'parliamentarian grub', 'public life –']
#     Paragraph common words: [('public', 4), ('again', 3), ('four', 2), ('year', 2), ('passed', 2)]
#
# Paragraph 10
#     Paragraph topics: [(0, '0.005*"democracy" + 0.005*"capacity"'), (1, '0.005*"democracy" + 0.005*"advance"'), (2, '0.032*"democracy" + 0.020*"would"')]
#     Paragraph sentiment: 0.10915178571428569
#     Paragraph nouns: ['scarcely', 'sober reality', 'spiritual training ground', 'bourgeois forces', 'marxism', 'parliamentary quacks', 'white race', 'inferior mental capacity', 'democracy', 'democracy', 'democracy', 'marxists', 'free hand', 'own methods', 'certain groups', 'marxists', 'critical occasions', 'majority vote', 'democracy', 'bourgeois parliamentarians', 'monumental shortsightedness', 'reich', 'numerical majority', 'marxists', 'supreme power', 'own hands', 'political place-hunters', 'jewish dilettanti', 'credulous parliamentary wizards', 'bourgeois democracy', 'brutal determination', 'marxist', 'magical formulas', 'parliamentarianism', 'marxism', 'own criminal purposes', 'marxism', 'marxists', "witch 's cauldron", 'parliamentary democracy', 'majority vote', 'numerical majority', 'marxism', 'whole parliamentarian hocus-pocus', 'democratic conscience', 'standard bearers', 'furious rallying-cry', 'proletarian masses', 'sedate atmosphere', 'intellectual prowess', 'proletarian masses –', 'bourgeois world', 'jewish drive', 'democracy']
#     Paragraph common words: [('democracy', 11), ('would', 7), ('western', 5), ('marxist', 5), ('bourgeois', 4)]
#
# Paragraph 11
#     Paragraph topics: [(0, '0.045*"serving" + 0.045*"discard"'), (1, '0.074*"rule" + 0.074*"mean"'), (2, '0.045*"could" + 0.045*"prove"')]
#     Paragraph sentiment: 0.03333333333333333
#     Paragraph nouns: ['credulous soul', 'mere bluff', 'own interests']
#     Paragraph common words: [('rule', 2), ('mean', 2), ('said', 1), ('credulous', 1), ('soul', 1)]
#
# Paragraph 12
#     Paragraph topics: [(0, '0.019*"political" + 0.019*"attracts"'), (1, '0.019*"absolute" + 0.019*"faith"'), (2, '0.030*"struggle" + 0.030*"mass"')]
#     Paragraph sentiment: 0.11125
#     Paragraph nouns: ['so-called bourgeois principles', 'political life', 'thrown overboard', 'sand ballast', 'such practice', 'great magnetic force', 'broad masses', 'absolute faith', 'indomitable zest']
#     Paragraph common words: [('party', 2), ('principle', 2), ('struggle', 2), ('force', 2), ('mass', 2)]
#
# Paragraph 13
#     Paragraph topics: [(0, '0.033*"–" + 0.025*"faith"'), (1, '0.011*"revolution" + 0.011*"thousand"'), (2, '0.011*"cowardly" + 0.011*"failed"')]
#     Paragraph sentiment: -0.17045454545454547
#     Paragraph nouns: ['systematic conception', 'life –', 'ways –', 'new faith', 'political faith', 'ruthless attack', 'present movement', 'so-called national bourgeois cabinet ministers –', 'bavarian', 'centre', 'example –', 'political pigmies', 'criminal stupidity', 'aggressive policy', 'new philosophy', 'indomitable devotion']
#     Paragraph common words: [('–', 4), ('faith', 3), ('one', 2), ('side', 2), ('life', 2)]
#
# Paragraph 14
#     Paragraph topics: [(0, '0.050*"care" + 0.050*"establishment"'), (1, '0.050*"faith" + 0.050*"fought"'), (2, '0.050*"special" + 0.050*"interest"')]
#     Paragraph sentiment: 0.1858766233766234
#     Paragraph nouns: ['special care', 'militant group', 'political faith', 'parliamentarian interests']
#     Paragraph common words: [('first', 1), ('stage', 1), ('founding', 1), ('movement', 1), ('take', 1)]
#
# Paragraph 15
#     Paragraph topics: [(0, '0.045*"make" + 0.045*"programme"'), (1, '0.045*"tend" + 0.045*"bulk"'), (2, '0.077*"would" + 0.044*"certain"')]
#     Paragraph sentiment: 0.061746031746031736
#     Paragraph nouns: ['preventive measure', 'certain moral greatness', 'present party politicians']
#     Paragraph common words: [('would', 2), ('first', 1), ('preventive', 1), ('measure', 1), ('lay', 1)]
#
# Paragraph 16
#     Paragraph topics: [(0, '0.053*"right" + 0.053*"afford"'), (1, '0.053*"right" + 0.053*"afford"'), (2, '0.053*"absolutely" + 0.053*"aim"')]
#     Paragraph sentiment: 0.09214285714285714
#     Paragraph nouns: ['fatal defects', 'germany', "'s downfall", 'clearest proof', 'programmatic aims']
#     Paragraph common words: [('fatal', 1), ('defect', 1), ('finally', 1), ('led', 1), ('germany', 1)]
#
# Paragraph 17
#     Paragraph topics: [(0, '0.083*"became" + 0.083*"defect"'), (1, '0.130*"new" + 0.130*"conception"'), (2, '0.083*"part" + 0.083*"defect"')]
#     Paragraph sentiment: 0.08068181818181819
#     Paragraph nouns: ['new conception', 'new conception']
#     Paragraph common words: [('new', 2), ('conception', 2), ('recognized', 1), ('defect', 1), ('mentioned', 1)]
#
# Paragraph 18
#     Paragraph topics: [(0, '0.083*"became" + 0.083*"defect"'), (1, '0.130*"new" + 0.130*"conception"'), (2, '0.083*"part" + 0.083*"defect"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 19
#     Paragraph topics: [(0, '0.083*"became" + 0.083*"defect"'), (1, '0.130*"new" + 0.130*"conception"'), (2, '0.083*"part" + 0.083*"defect"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 20
#     Paragraph topics: [(0, '0.083*"became" + 0.083*"defect"'), (1, '0.130*"new" + 0.130*"conception"'), (2, '0.083*"part" + 0.083*"defect"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 21
#     Paragraph topics: [(0, '0.083*"became" + 0.083*"defect"'), (1, '0.130*"new" + 0.130*"conception"'), (2, '0.083*"part" + 0.083*"defect"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 22
#     Paragraph topics: [(0, '0.006*"religious" + 0.006*"word"'), (1, '0.006*"banner" + 0.006*"highest"'), (2, '0.020*"word" + 0.020*"religious"')]
#     Paragraph sentiment: 0.10579212454212455
#     Paragraph nouns: ['term völkisch', 'precise meaning', 'militant community', 'divergent opinions', 'present moment', 'device völkisch', 'labour', 'clear understanding', 'concept völkisch', 'party movement', 'word völkisch', 'practical application', "word 'religious", 'precise meaning', 'theoretical concept', 'practical life', "word 'religious", 'precise meaning', 'definite form', 'fine phraseology', 'vague description', 'word conveys', 'definite picture', 'inner quality', 'religious idea', 'practical faith', 'general metaphysical ideas', 'definite dogmatic belief', 'profound vital need', 'sublime beauty owes', 'beautiful form']
#     Paragraph common words: [('word', 5), ('religious', 5), ('völkisch', 4), ('may', 4), ('practical', 4)]
#
# Paragraph 23
#     Paragraph topics: [(0, '0.018*"moral" + 0.018*"humanity"'), (1, '0.018*"safeguard" + 0.018*"seriously"'), (2, '0.051*"existence" + 0.039*"human"')]
#     Paragraph sentiment: 0.0051834130781499175
#     Paragraph nouns: ['mere animal existence', 'faith', 'own existence', 'religious beliefs', 'moral standards', 'practical life', 'religious teaching', 'equal value', 'human existence', 'necessary conditions']
#     Paragraph common words: [('existence', 4), ('human', 3), ('taking', 2), ('religious', 2), ('serve', 2)]
#
# Paragraph 24
#     Paragraph topics: [(0, '0.020*"emotional" + 0.020*"outlet"'), (1, '0.020*"word" + 0.020*"among"'), (2, '0.059*"belief" + 0.032*"idea"')]
#     Paragraph sentiment: 0.001515151515151516
#     Paragraph nouns: ["word 'religious", 'future existence', 'emotional concept', 'active service', 'doctrinal faith', 'faith furnishes', 'practical outlet', 'religious feeling']
#     Paragraph common words: [('belief', 4), ('religious', 2), ('idea', 2), ('may', 2), ('existence', 2)]
#
# Paragraph 25
#     Paragraph topics: [(0, '0.048*"religious" + 0.048*"purpose"'), (1, '0.048*"human" + 0.048*"clearly"'), (2, '0.048*"contribute" + 0.048*"tendency"')]
#     Paragraph sentiment: -0.16428571428571428
#     Paragraph nouns: ['religious feeling', 'human existence', 'general disorganization', 'multifarious tendencies']
#     Paragraph common words: [('without', 1), ('clearly', 1), ('defined', 1), ('belief', 1), ('religious', 1)]
#
# Paragraph 26
#     Paragraph topics: [(0, '0.016*"sentiment" + 0.016*"structure"'), (1, '0.046*"ideal" + 0.025*"word"'), (2, '0.016*"indefinite" + 0.016*"consequence"')]
#     Paragraph sentiment: 0.06421428571428571
#     Paragraph nouns: ["word 'religious", 'term völkisch', 'certain fundamental ideas', 'such vague', 'indefinite forms', 'mere opinions', 'constituent elements', 'political party', 'practical force', 'philosophical ideals', 'logical consequence', 'such ideals', 'mere sentiment', 'practical assistance', 'military force', 'urgent wish', 'potent reality']
#     Paragraph common words: [('ideal', 4), ('word', 2), ('also', 2), ('idea', 2), ('cannot', 2)]
#
# Paragraph 27
#     Paragraph topics: [(0, '0.025*"militant" + 0.025*"side"'), (1, '0.042*"movement" + 0.042*"party"'), (2, '0.025*"highest" + 0.025*"doctrine"')]
#     Paragraph sentiment: 0.037272727272727256
#     Paragraph nouns: ['practical service', 'militant movement', 'own side', 'mere party', 'party doctrines', 'new foundations', 'national community', 'final shape']
#     Paragraph common words: [('movement', 2), ('party', 2), ('every', 1), ('philosophy', 1), ('life', 1)]
#
# Paragraph 28
#     Paragraph topics: [(0, '0.012*"knowledge" + 0.012*"draw"'), (1, '0.012*"strength" + 0.012*"statesman"'), (2, '0.057*"must" + 0.036*"practical"')]
#     Paragraph sentiment: 0.132
#     Paragraph nouns: ['abstract conception', 'general nature', 'future development', 'clear understanding', 'internal cohesion', 'general ideas', 'political programme', 'general ideas', 'definite political faith', 'practical reality', 'practical wisdom', 'abstract idea', 'human frailty', 'practical effect', 'practical knowledge', 'eternal verities', 'human nature', 'practical form']
#     Paragraph common words: [('must', 8), ('general', 5), ('practical', 5), ('ideal', 4), ('nature', 3)]
#
# Paragraph 29
#     Paragraph topics: [(0, '0.015*"rock" + 0.015*"dependent"'), (1, '0.015*"able" + 0.015*"feel"'), (2, '0.047*"idea" + 0.038*"must"')]
#     Paragraph sentiment: 0.08913043478260871
#     Paragraph nouns: ['general principles', 'solid foundation', 'militant community', 'political faith –', 'important task', 'successful fulfilment', 'expound general ideas', 'definite form', 'vague ideas', 'formulate principles', 'true ones', 'solid rock', 'common faith', 'vagrant ideas']
#     Paragraph common words: [('idea', 5), ('one', 4), ('must', 4), ('principle', 3), ('general', 2)]
#
# Paragraph 30
#     Paragraph topics: [(0, '0.125*"action" + 0.125*"general"'), (1, '0.125*"action" + 0.125*"general"'), (2, '0.125*"action" + 0.125*"justified"')]
#     Paragraph sentiment: 0.1416666666666667
#     Paragraph nouns: ['general justification', 'such action']
#     Paragraph common words: [('general', 1), ('justification', 1), ('action', 1), ('sought', 1), ('necessity', 1)]
#
# Paragraph 31
#     Paragraph topics: [(0, '0.125*"action" + 0.125*"general"'), (1, '0.125*"action" + 0.125*"general"'), (2, '0.125*"action" + 0.125*"justified"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 32
#     Paragraph topics: [(0, '0.125*"action" + 0.125*"general"'), (1, '0.125*"action" + 0.125*"general"'), (2, '0.125*"action" + 0.125*"justified"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 33
#     Paragraph topics: [(0, '0.125*"action" + 0.125*"general"'), (1, '0.125*"action" + 0.125*"general"'), (2, '0.125*"action" + 0.125*"justified"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 34
#     Paragraph topics: [(0, '0.111*"inner" + 0.111*"following"'), (1, '0.111*"penetrate" + 0.111*"following"'), (2, '0.111*"conclusion" + 0.111*"arrive"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: ['inner meaning', 'word völkisch']
#     Paragraph common words: [('try', 1), ('penetrate', 1), ('inner', 1), ('meaning', 1), ('word', 1)]
#
# Paragraph 35
#     Paragraph topics: [(0, '0.034*"state" + 0.023*"race"'), (1, '0.009*"affected" + 0.009*"profession"'), (2, '0.009*"solution" + 0.009*"poison"')]
#     Paragraph sentiment: 0.061290322580645165
#     Paragraph nouns: ['current political conception', 'creative force', 'economic necessity', 'natural outcome', 'political forces', 'logical consequences', 'racial forces', 'cultural creativeness', 'erroneous notion', 'marxism', 'application –', 'jew', 'karl marx', 'general conception', 'definite profession', 'political faith', 'general concept', 'karl marx', 'amazing political progress', 'marxist', 'karl marx', 'gradual decomposition', 'keen powers', 'essential poisons', 'rapid destruction', 'independent nations']
#     Paragraph common words: [('state', 6), ('political', 4), ('race', 4), ('conception', 3), ('force', 3)]
#
# Paragraph 36
#     Paragraph topics: [(0, '0.021*"aim" + 0.021*"bourgeoisie"'), (1, '0.021*"even" + 0.021*"hand"'), (2, '0.070*"world" + 0.044*"bourgeois"')]
#     Paragraph sentiment: 0.13511904761904764
#     Paragraph nouns: ['marxist', 'general concept', 'bourgeois world', 'effective fight', 'marxism', 'bourgeois world', 'general differs', 'marxism', 'bourgeois world', 'marxist', 'certain group', 'people –', 'bourgeoisie –', 'marxism', 'jews']
#     Paragraph common words: [('world', 5), ('bourgeois', 3), ('marxism', 3), ('marxist', 2), ('general', 2)]
#
# Paragraph 37
#     Paragraph topics: [(0, '0.010*"aristocratic" + 0.010*"universe"'), (1, '0.033*"ideal" + 0.033*"principle"'), (2, '0.010*"condition" + 0.010*"conservation"')]
#     Paragraph sentiment: 0.24341630591630595
#     Paragraph nouns: ['völkisch concept', 'racial elements', 'racial characteristics', 'völkisch principle', 'völkisch concept separates mankind', 'inferior quality', 'will', 'nature', "'s operations", 'aristocratic principle', 'individual organism', 'individual values', 'marxism', 'völkisch belief', 'necessary condition', 'human existence', 'human beauty']
#     Paragraph common words: [('principle', 5), ('ideal', 5), ('völkisch', 4), ('mankind', 3), ('race', 3)]
#
# Paragraph 38
#     Paragraph topics: [(0, '0.056*"barbarian" + 0.056*"civilization"'), (1, '0.056*"exterminated" + 0.056*"barbarian"'), (2, '0.056*"shroud" + 0.056*"would"')]
#     Paragraph sentiment: -0.1784090909090909
#     Paragraph nouns: ['human culture', 'aryan', 'dark shroud', 'new barbarian era']
#     Paragraph common words: [('planet', 1), ('human', 1), ('culture', 1), ('civilization', 1), ('indissolubly', 1)]
#
# Paragraph 39
#     Paragraph topics: [(0, '0.031*"lie" + 0.031*"believe"'), (1, '0.091*"would" + 0.049*"existence"'), (2, '0.031*"bountiful" + 0.031*"folkidea"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: ['human culture', 'execrable crime', 'human existence', 'whoever', 'profane hand', 'god', 'creator']
#     Paragraph common words: [('would', 4), ('existence', 2), ('human', 2), ('undermine', 1), ('culture', 1)]
#
# Paragraph 40
#     Paragraph topics: [(0, '0.047*"earth" + 0.047*"free"'), (1, '0.029*"concept" + 0.029*"every"'), (2, '0.029*"towards" + 0.029*"higher"')]
#     Paragraph sentiment: 0.30476190476190473
#     Paragraph nouns: ['hence', 'folk concept', 'profound accord', 'nature', 'free play', 'reciprocal education']
#     Paragraph common words: [('world', 2), ('free', 2), ('earth', 2), ('hence', 1), ('folk', 1)]
#
# Paragraph 41
#     Paragraph topics: [(0, '0.048*"distant" + 0.048*"destined"'), (1, '0.048*"mean" + 0.048*"superior"'), (2, '0.080*"race" + 0.046*"master"')]
#     Paragraph sentiment: 0.146875
#     Paragraph nouns: ['distant future', 'superior race', 'human beings', 'whole world']
#     Paragraph common words: [('race', 2), ('feel', 1), ('distant', 1), ('future', 1), ('many', 1)]
#
# Paragraph 42
#     Paragraph topics: [(0, '0.048*"distant" + 0.048*"destined"'), (1, '0.048*"mean" + 0.048*"superior"'), (2, '0.080*"race" + 0.046*"master"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 43
#     Paragraph topics: [(0, '0.048*"distant" + 0.048*"destined"'), (1, '0.048*"mean" + 0.048*"superior"'), (2, '0.080*"race" + 0.046*"master"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 44
#     Paragraph topics: [(0, '0.048*"distant" + 0.048*"destined"'), (1, '0.048*"mean" + 0.048*"superior"'), (2, '0.080*"race" + 0.046*"master"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 45
#     Paragraph topics: [(0, '0.013*"meaningful" + 0.013*"footing"'), (1, '0.013*"truth" + 0.013*"led"'), (2, '0.028*"conception" + 0.028*"way"')]
#     Paragraph sentiment: 0.06516164994425865
#     Paragraph nouns: ['meaningful content', 'folkish philosophy', 'different ways', 'recent political movements', 'independent existence', 'others proves', 'marxist', 'central organization', 'supreme authority', 'motley crew', 'solid phalanx', 'victory', 'such weak weapons', 'international idea', 'marxism', 'folk idea', 'systematic way', 'eternal truth']
#     Paragraph common words: [('way', 3), ('conception', 3), ('fact', 2), ('one', 2), ('world', 2)]
#
# Paragraph 46
#     Paragraph topics: [(0, '0.043*"built" + 0.043*"never"'), (1, '0.071*"function" + 0.071*"party"'), (2, '0.043*"belief" + 0.043*"dogma"')]
#     Paragraph sentiment: 0.07500000000000001
#     Paragraph nouns: ['general conception', 'organic embodiment', 'dogma fulfils', 'religious belief', 'party principles fulfil', 'political party']
#     Paragraph common words: [('function', 2), ('party', 2), ('general', 1), ('conception', 1), ('life', 1)]
#
# Paragraph 47
#     Paragraph topics: [(0, '0.053*"fighting" + 0.053*"ideal"'), (1, '0.053*"forged" + 0.053*"instrument"'), (2, '0.053*"folk" + 0.053*"organization"')]
#     Paragraph sentiment: 0.3
#     Paragraph nouns: ['folk idea', 'marxist', 'party organization']
#     Paragraph common words: [('therefore', 1), ('conception', 1), ('life', 1), ('based', 1), ('folk', 1)]
#
# Paragraph 48
#     Paragraph topics: [(0, '0.143*"national" + 0.143*"party"'), (1, '0.143*"german" + 0.143*"goal"'), (2, '0.143*"socialist" + 0.143*"goal"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: [('goal', 1), ('pursued', 1), ('national', 1), ('socialist', 1), ('german', 1)]
#
# Paragraph 49
#     Paragraph topics: [(0, '0.039*"idea" + 0.027*"party"'), (1, '0.010*"article" + 0.010*"cannot"'), (2, '0.010*"give" + 0.010*"organization"')]
#     Paragraph sentiment: 0.09846560846560848
#     Paragraph nouns: ['folk conception', 'necessary prerequisite', 'indirect acknowledgment', 'folk idea', 'party principles', 'folk idea', 'exclusive property', 'own statements', 'simple fact', 'general presence', 'such ideas', 'political party', 'class conflict', 'german people', 'gigantic victory', 'international ideology', 'political party', 'international concept', 'definite outlook', 'free interpretation', 'general teaching', 'certain articles', 'political organization']
#     Paragraph common words: [('idea', 6), ('party', 4), ('folk', 3), ('life', 3), ('political', 3)]
#
# Paragraph 50
#     Paragraph topics: [(0, '0.015*"human" + 0.015*"uniting"'), (1, '0.033*"principle" + 0.033*"world"'), (2, '0.015*"party" + 0.015*"dogmatic"')]
#     Paragraph sentiment: 0.07728571428571429
#     Paragraph nouns: ['special duty', 'vague contents', 'general world view', 'dogmatic form', 'clear meaning', 'common front', 'party extracts', 'essential principles', 'general conception', 'folk idea', 'political doctrine', 'practical realities', 'available human material', 'political doctrine', 'great masses', 'final triumph', 'world view']
#     Paragraph common words: [('world', 3), ('idea', 3), ('principle', 3), ('extract', 2), ('general', 2)]
#
# Paragraph 51
#     Paragraph topics: [(0, '0.007*"belonging" + 0.007*"discussion"'), (1, '0.043*"state" + 0.025*"purpose"'), (2, '0.007*"le" + 0.007*"assumed"')]
#     Paragraph sentiment: 0.13249528249528247
#     Paragraph nouns: ['certain circles', 'bourgeois class', 'negative attitude', 'modern state', 'motley gang', 'camp followers', 'various political parties', 'heterogeneous conglomeration', 'political views', 'available means', 'young movement', 'new political gospel', 'bourgeois class', 'uniform opinion', 'coherent definition', 'state universities', 'constitutional law', 'fortunate existence', 'particular form', 'daily bread', 'imperial university professor', 'statal form', 'twentieth century', 'contemporary professor', 'constitutional law', 'certain definite purpose', 'monstrous human mechanism', 'concrete facts', 'abstract values']
#     Paragraph common words: [('state', 9), ('purpose', 5), ('political', 3), ('fact', 3), ('duty', 3)]
#
# Paragraph 52
#     Paragraph topics: [(0, '0.125*"may" + 0.125*"theorist"'), (1, '0.125*"generally" + 0.125*"may"'), (2, '0.125*"classed" + 0.125*"speaking"')]
#     Paragraph sentiment: 0.02500000000000001
#     Paragraph nouns: ['various theorists']
#     Paragraph common words: [('generally', 1), ('speaking', 1), ('various', 1), ('theorist', 1), ('may', 1)]
#
# Paragraph 53
#     Paragraph topics: [(0, '0.083*"hold" + 0.083*"association"'), (1, '0.083*"ruling" + 0.083*"agreed"'), (2, '0.083*"voluntary" + 0.083*"agreed"')]
#     Paragraph sentiment: 0.16666666666666669
#     Paragraph nouns: ['voluntary association', 'ruling authority']
#     Paragraph common words: [('1', 1), ('hold', 1), ('state', 1), ('le', 1), ('voluntary', 1)]
#
# Paragraph 54
#     Paragraph topics: [(0, '0.045*"state" + 0.026*"authority"'), (1, '0.010*"largest" + 0.010*"simply"'), (2, '0.010*"become" + 0.010*"blackandyellow"')]
#     Paragraph sentiment: -0.05998075998075999
#     Paragraph nouns: ['present principle', 'whole affair', 'state exists', 'sufficient reason', 'human brains', 'dog-like adoration', 'so-called state authority', 'sleight-of-hand movement', 'ecstatic adoration', 'therewith', 'public peace', 'bavaria', 'artful politicians', 'bavarian centre', 'populist', 'austria', 'black-and-yellow', 'similar attitude', 'reich', 'so-called conservative elements']
#     Paragraph common words: [('state', 7), ('authority', 4), ('order', 3), ('must', 3), ('people', 2)]
#
# Paragraph 55
#     Paragraph topics: [(0, '0.011*"concept" + 0.011*"though"'), (1, '0.011*"wellbeing" + 0.011*"used"'), (2, '0.045*"state" + 0.024*"exists"')]
#     Paragraph sentiment: 0.0976190476190476
#     Paragraph nouns: ['uniform system', 'technical reasons', 'exclusive end', 'state exists', 'ideas', 'practical efficiency', 'venerable age', 'modern exigencies', 'individual citizens', 'hence', 'practical standpoint', 'general principles', 'economic returns', 'chief representatives', 'german', 'liberal democrats']
#     Paragraph common words: [('state', 6), ('longer', 3), ('exists', 3), ('group', 2), ('government', 2)]
#
# Paragraph 56
#     Paragraph topics: [(0, '0.021*"direction" + 0.021*"postulated"'), (1, '0.045*"power" + 0.045*"language"'), (2, '0.021*"hope" + 0.021*"furnished"')]
#     Paragraph sentiment: -0.030208333333333334
#     Paragraph nouns: ['common language', 'solid basis', 'own frontiers', 'fundamental error', 'common language', 'definite direction']
#     Paragraph common words: [('power', 3), ('language', 3), ('state', 2), ('mean', 2), ('tendency', 2)]
#
# Paragraph 57
#     Paragraph topics: [(0, '0.009*"notion" + 0.009*"mostly"'), (1, '0.009*"rise" + 0.009*"understand"'), (2, '0.039*"german" + 0.028*"people"')]
#     Paragraph sentiment: 0.07016129032258064
#     Paragraph nouns: ["word 'germanize", 'incredible degree', 'pan-german', 'austrian germans', 'germanizing', 'austrian slavs', 'germanization', 'regards human beings', 'germanization', 'german language', 'negro', 'chinaman', 'german language', 'german political party', 'bourgeois nationalists', 'germanization', 'reality de-germanization', 'visible differences', 'various peoples', 'common language', 'germanization', 'german element', 'external force']
#     Paragraph common words: [('german', 7), ('people', 5), ('germanization', 4), ('language', 4), ('well', 3)]
#
# Paragraph 58
#     Paragraph topics: [(0, '0.012*"example" + 0.012*"conquering"'), (1, '0.052*"race" + 0.045*"would"'), (2, '0.012*"creativeness" + 0.012*"descendant"')]
#     Paragraph sentiment: 0.1989858906525573
#     Paragraph nouns: ['germanization', 'superior race', 'final result', 'inferior people', 'cultural creativeness', 'superior race intermixes', 'resultant mongrel race', 'certain time', 'different mentalities', 'progressive degeneration', 'moment rally', 'cultural creative power', 'superior race', 'superior blood', 'final descendants', 'such hybrids', 'cultural retrogression']
#     Paragraph common words: [('race', 7), ('would', 6), ('superior', 5), ('blood', 4), ('people', 3)]
#
# Paragraph 59
#     Paragraph topics: [(0, '0.024*"time" + 0.024*"century"'), (1, '0.085*"would" + 0.037*"state"'), (2, '0.024*"probably" + 0.024*"plan"')]
#     Paragraph sentiment: 0.1767857142857143
#     Paragraph nouns: ['germanization', 'austria', 'joseph ii', 'austrian', 'time participation', 'common language', 'racial quality', 'german element', 'certain herd instinct', 'national state']
#     Paragraph common words: [('would', 5), ('state', 2), ('quality', 2), ('herd', 2), ('might', 2)]
#
# Paragraph 60
#     Paragraph topics: [(0, '0.074*"german" + 0.074*"place"'), (1, '0.045*"although" + 0.045*"renounced"'), (2, '0.045*"simply" + 0.045*"taken"')]
#     Paragraph sentiment: 0.12
#     Paragraph nouns: ['german nation', 'habsburgs', 'german people', 'cultural factor']
#     Paragraph common words: [('german', 2), ('place', 2), ('nation', 1), ('better', 1), ('process', 1)]
#
# Paragraph 61
#     Paragraph topics: [(0, '0.021*"based" + 0.021*"nation"'), (1, '0.046*"german" + 0.032*"use"'), (2, '0.021*"erroneous" + 0.021*"also"')]
#     Paragraph sentiment: -0.04230769230769232
#     Paragraph nouns: ['austria', 'reich', 'so-called national circles', 'similar erroneous ideas', 'poland', 'germanized', 'false reasoning', 'polish', 'germanized', 'german language', 'foreign race', 'german language', 'express modes', 'own inferiority']
#     Paragraph common words: [('german', 3), ('germanized', 2), ('people', 2), ('use', 2), ('language', 2)]
#
# Paragraph 62
#     Paragraph topics: [(0, '0.117*"german" + 0.043*"think"'), (1, '0.028*"many" + 0.028*"fact"'), (2, '0.028*"many" + 0.028*"among"')]
#     Paragraph sentiment: 0.07777777777777778
#     Paragraph nouns: ['german prestige', 'german patois', 'jews', 'germans', 'german conditions', 'unhygienic immigrants', 'german race']
#     Paragraph common words: [('german', 6), ('think', 2), ('revolting', 1), ('much', 1), ('damage', 1)]
#
# Paragraph 63
#     Paragraph topics: [(0, '0.031*"extent" + 0.031*"character"'), (1, '0.053*"german" + 0.031*"colonization"'), (2, '0.031*"ancestor" + 0.031*"even"')]
#     Paragraph sentiment: -0.015277777777777774
#     Paragraph nouns: ['germanized', 'german tillers', 'foreign blood', 'national body', 'racial character', 'german hyper-individualism']
#     Paragraph common words: [('german', 2), ('beneficially', 1), ('germanized', 1), ('course', 1), ('history', 1)]
#
# Paragraph 64
#     Paragraph topics: [(0, '0.077*"consider" + 0.044*"existence"'), (1, '0.045*"may" + 0.045*"also"'), (2, '0.045*"group" + 0.045*"itself"')]
#     Paragraph sentiment: 0.07142857142857142
#     Paragraph nouns: ['certain degree', 'hence', 'human existence']
#     Paragraph common words: [('consider', 2), ('third', 1), ('group', 1), ('also', 1), ('people', 1)]
#
# Paragraph 65
#     Paragraph topics: [(0, '0.033*"essentially" + 0.033*"grounded"'), (1, '0.033*"capacity" + 0.033*"based"'), (2, '0.033*"creating" + 0.033*"race"')]
#     Paragraph sentiment: 0.04722222222222222
#     Paragraph nouns: ['profound truth', 'cultural values', 'racial element', 'paramount purpose', 'indispensable condition', 'human civilization']
#     Paragraph common words: [('opinion', 1), ('common', 1), ('feature', 1), ('failing', 1), ('grounded', 1)]
#
# Paragraph 66
#     Paragraph topics: [(0, '0.030*"reject" + 0.030*"accepted"'), (1, '0.030*"way" + 0.030*"such"'), (2, '0.090*"state" + 0.049*"concept"')]
#     Paragraph sentiment: -0.00416666666666668
#     Paragraph nouns: ['jew', 'karl marx', 'final conclusions', 'false concepts', 'state bears']
#     Paragraph common words: [('state', 4), ('concept', 2), ('thus', 1), ('jew', 1), ('karl', 1)]
#
# Paragraph 67
#     Paragraph topics: [(0, '0.031*"could" + 0.031*"furnish"'), (1, '0.053*"bourgeois" + 0.031*"crafty"'), (2, '0.031*"perceived" + 0.031*"solid"')]
#     Paragraph sentiment: 0.020000000000000007
#     Paragraph nouns: ['bourgeois struggle', 'marxist', 'bourgeois classes', 'basic principles', 'crafty opponent']
#     Paragraph common words: [('bourgeois', 2), ('struggle', 1), ('marxist', 1), ('internationalism', 1), ('absolutely', 1)]
#
# Paragraph 68
#     Paragraph topics: [(0, '0.062*"based" + 0.062*"clear"'), (1, '0.063*"logical" + 0.063*"nature"'), (2, '0.063*"racial" + 0.063*"first"')]
#     Paragraph sentiment: 0.18409090909090908
#     Paragraph nouns: ['new movement', 'racial concept', 'logical doctrine']
#     Paragraph common words: [('therefore', 1), ('new', 1), ('movement', 1), ('based', 1), ('racial', 1)]
#
# Paragraph 69
#     Paragraph topics: [(0, '0.016*"also" + 0.016*"preliminary"'), (1, '0.034*"may" + 0.034*"human"'), (2, '0.016*"say" + 0.016*"alone"')]
#     Paragraph sentiment: 0.16372549019607843
#     Paragraph nouns: ['fundamental principle', 'preliminary condition', 'human civilization', 'actual existence', 'cultural creativeness', 'aryan', 'adequate level', 'spiritual needs', 'superior nations', 'human beings', 'human race', 'superior intellectual faculties', 'racial bearer']
#     Paragraph common words: [('state', 3), ('human', 3), ('may', 3), ('end', 2), ('civilization', 2)]
#
# Paragraph 70
#     Paragraph topics: [(0, '0.009*"sea" + 0.009*"vestige"'), (1, '0.009*"however" + 0.009*"desert"'), (2, '0.042*"would" + 0.025*"race"')]
#     Paragraph sentiment: 0.03936237373737373
#     Paragraph nouns: ['seismic convulsion', 'himalaya', 'annihilate human civilization', 'cultural products', 'tremendous field', 'terrible havoc', 'definite race', 'innate powers', 'creative power', 'human spirit', 'cultural creativeness', 'modern history furnishes examples', 'statal institutions', 'creative genius', 'prehistoric animals', 'definite faculty', 'own existence']
#     Paragraph common words: [('would', 7), ('race', 4), ('if', 2), ('one', 2), ('might', 2)]
#
# Paragraph 71
#     Paragraph topics: [(0, '0.019*"present" + 0.019*"hundred"'), (1, '0.019*"year" + 0.019*"certain"'), (2, '0.065*"state" + 0.040*"cultural"')]
#     Paragraph sentiment: 0.010544217687074834
#     Paragraph nouns: ['certain definite advance', 'cultural progress', 'such progress', 'cultural faculties', 'general life', 'profound changes', 'racial mixture', 'present state', 'mere mechanical form', 'national body', 'cultural decadence', 'various symptoms', 'detrimental character']
#     Paragraph common words: [('state', 5), ('cultural', 3), ('may', 3), ('brings', 2), ('progress', 2)]
#
# Paragraph 72
#     Paragraph topics: [(0, '0.071*"thus" + 0.071*"indispensable"'), (1, '0.071*"indispensable" + 0.071*"producing"'), (2, '0.113*"human" + 0.113*"quality"')]
#     Paragraph sentiment: 0.25833333333333336
#     Paragraph nouns: ['indispensable prerequisite', 'superior quality', 'human beings', 'human quality']
#     Paragraph common words: [('quality', 2), ('human', 2), ('thus', 1), ('indispensable', 1), ('prerequisite', 1)]
#
# Paragraph 73
#     Paragraph topics: [(0, '0.010*"eskimo" + 0.010*"speak"'), (1, '0.051*"faculty" + 0.020*"climate"'), (2, '0.010*"become" + 0.010*"it"')]
#     Paragraph sentiment: 0.17191558441558444
#     Paragraph nouns: ['lie dormant', 'external circumstances awaken', 'cultural creativeness', 'latent form', 'external circumstances', 'germans', 'northern regions', 'free development', 'creative faculties', 'fairer climate', 'previous culture whatsoever', 'necessary human material –', 'inferior race –', 'cultural faculty dormant', 'greeks', 'creative faculty', 'cultural things', 'northern climate', 'laplanders', 'eskimos', 'wonderful creative faculty', 'special gift', 'aryan', 'adverse conditions', 'active expression', 'favourable circumstances']
#     Paragraph common words: [('faculty', 8), ('dormant', 3), ('circumstance', 3), ('cultural', 3), ('climate', 3)]
#
# Paragraph 74
#     Paragraph topics: [(0, '0.200*"conclusion" + 0.200*"drawn"'), (1, '0.200*"conclusion" + 0.200*"drawn"'), (2, '0.200*"fact" + 0.200*"may"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: [('fact', 1), ('following', 1), ('conclusion', 1), ('may', 1), ('drawn', 1)]
#
# Paragraph 75
#     Paragraph topics: [(0, '0.048*"race" + 0.033*"existence"'), (1, '0.021*"mean" + 0.021*"field"'), (2, '0.021*"portion" + 0.021*"employed"')]
#     Paragraph sentiment: 0.1359375
#     Paragraph nouns: ['human beings', 'indispensable condition', 'free development', 'forces dormant', 'great part', 'physical existence', 'small portion', 'intellectual progress', 'necessary counterpart']
#     Paragraph common words: [('race', 3), ('end', 2), ('preserve', 2), ('existence', 2), ('free', 2)]
#
# Paragraph 76
#     Paragraph topics: [(0, '0.152*"justification" + 0.061*"carried"'), (1, '0.067*"band" + 0.067*"carried"'), (2, '0.067*"band" + 0.067*"pirate"')]
#     Paragraph sentiment: 0.25
#     Paragraph nouns: ['successful raids']
#     Paragraph common words: [('justification', 3), ('state', 1), ('serve', 1), ('purpose', 1), ('existence', 1)]
#
# Paragraph 77
#     Paragraph topics: [(0, '0.025*"otherwise" + 0.025*"so"'), (1, '0.025*"protagonist" + 0.025*"worthless"'), (2, '0.056*"vessel" + 0.039*"content"')]
#     Paragraph sentiment: 0.09659090909090909
#     Paragraph nouns: ['socialists', 'new philosophy', "famous 'basis", 'mistaken facts', 'great idea', 'clear-cut distinction', 'otherwise']
#     Paragraph common words: [('vessel', 3), ('new', 2), ('must', 2), ('fact', 2), ('content', 2)]
#
# Paragraph 78
#     Paragraph topics: [(0, '0.026*"development" + 0.026*"lead"'), (1, '0.059*"people" + 0.041*"organism"'), (2, '0.026*"element" + 0.026*"higher"')]
#     Paragraph sentiment: 0.14537037037037037
#     Paragraph nouns: ['hence', 'supreme purpose', 'folkish state', 'original racial elements', 'cultural field', 'aryans', 'supreme liberty', 'progressive development', 'cultural faculties']
#     Paragraph common words: [('people', 3), ('supreme', 2), ('state', 2), ('cultural', 2), ('organism', 2)]
#
# Paragraph 79
#     Paragraph topics: [(0, '0.059*"brings" + 0.059*"case"'), (1, '0.059*"aberration" + 0.059*"want"'), (2, '0.059*"aberration" + 0.059*"untold"')]
#     Paragraph sentiment: 0.19444444444444445
#     Paragraph nouns: ['profound human aberration']
#     Paragraph common words: [('want', 1), ('impose', 1), ('upon', 1), ('u', 1), ('state', 1)]
#
# Paragraph 80
#     Paragraph topics: [(0, '0.031*"world" + 0.031*"holding"'), (1, '0.031*"approbation" + 0.031*"determined"'), (2, '0.050*"today" + 0.050*"view"')]
#     Paragraph sentiment: 0.09523809523809523
#     Paragraph nouns: ['socialists', 'revolutionary stand', 'clearer insight', 'right work']
#     Paragraph common words: [('view', 2), ('revolutionary', 2), ('today', 2), ('work', 2), ('national', 1)]
#
# Paragraph 81
#     Paragraph topics: [(0, '0.031*"world" + 0.031*"holding"'), (1, '0.031*"approbation" + 0.031*"determined"'), (2, '0.050*"today" + 0.050*"view"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 82
#     Paragraph topics: [(0, '0.031*"world" + 0.031*"holding"'), (1, '0.031*"approbation" + 0.031*"determined"'), (2, '0.050*"today" + 0.050*"view"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 83
#     Paragraph topics: [(0, '0.031*"world" + 0.031*"holding"'), (1, '0.031*"approbation" + 0.031*"determined"'), (2, '0.050*"today" + 0.050*"view"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 84
#     Paragraph topics: [(0, '0.031*"world" + 0.031*"holding"'), (1, '0.031*"approbation" + 0.031*"determined"'), (2, '0.050*"today" + 0.050*"view"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: []
#     Paragraph common words: []
#
# Paragraph 85
#     Paragraph topics: [(0, '0.050*"nation" + 0.050*"viewed"'), (1, '0.050*"word" + 0.050*"base"'), (2, '0.081*"standpoint" + 0.081*"value"')]
#     Paragraph sentiment: -0.051190476190476196
#     Paragraph nouns: ['socialists', 'particular standpoint', 'individual nation']
#     Paragraph common words: [('value', 2), ('standpoint', 2), ('principle', 1), ('national', 1), ('socialist', 1)]
#
# Paragraph 86
#     Paragraph topics: [(0, '0.050*"quality" + 0.050*"excellence"'), (1, '0.081*"judged" + 0.081*"degree"'), (2, '0.050*"belongs" + 0.050*"world"')]
#     Paragraph sentiment: 0.0
#     Paragraph nouns: ['outside world attaches', 'racial stock']
#     Paragraph common words: [('judged', 2), ('degree', 2), ('quality', 1), ('state', 1), ('never', 1)]
#
# Paragraph 87
#     Paragraph topics: [(0, '0.010*"human" + 0.010*"fruit"'), (1, '0.052*"state" + 0.030*"may"'), (2, '0.010*"policy" + 0.010*"allowing"')]
#     Paragraph sentiment: 0.1113978494623656
#     Paragraph nouns: ['model example', 'vital needs', 'racial stock', 'own existence', 'racial stock', 'general cultural significance', 'statal institution', 'human capabilities', 'free scope', 'high cultural level', 'racial uniformity', 'practical effect', 'ulterior existence', 'creative power', 'racial stock', 'cultural level', 'high creative powers', 'cultural sphere', 'statal organization', 'statal institutions', 'evolve faculties', 'bad state', 'racial culture']
#     Paragraph common words: [('state', 9), ('may', 5), ('racial', 5), ('existence', 4), ('cultural', 4)]
#
# Paragraph 88
#     Paragraph topics: [(0, '0.069*"worth" + 0.069*"state"'), (1, '0.030*"role" + 0.030*"play"'), (2, '0.030*"accurately" + 0.030*"belong"')]
#     Paragraph sentiment: 0.13613445378151262
#     Paragraph nouns: ['definite race', 'cultural level', 'individual state']
#     Paragraph common words: [('worth', 3), ('state', 3), ('therefore', 1), ('determined', 1), ('asking', 1)]
#
# Paragraph 89
#     Paragraph topics: [(0, '0.030*"kind" + 0.030*"institution"'), (1, '0.030*"statal" + 0.030*"furnishing"'), (2, '0.080*"must" + 0.062*"state"')]
#     Paragraph sentiment: 0.27125
#     Paragraph nouns: ['high mission', 'high mission', 'necessary conditions', 'creative faculties', 'statal institution', 'germans', 'clear notion']
#     Paragraph common words: [('must', 4), ('state', 3), ('people', 3), ('high', 2), ('mission', 2)]
#
# Paragraph 90
#     Paragraph topics: [(0, '0.006*"difference" + 0.006*"interior"'), (1, '0.025*"element" + 0.018*"german"'), (2, '0.006*"intermingling" + 0.006*"among"')]
#     Paragraph sentiment: 0.012309912309912309
#     Paragraph nouns: ['racial type', 'original elements', 'new race', 'national body', 'thirty years', 'uniform constitution', 'national soul', 'open frontiers', 'native country', 'foreign elements', 'foreign blood', 'reich', 'complete assimilation', 'various elements', 'new race', 'heterogeneous elements', 'germans', 'fundamental racial elements', 'different districts', 'various elements', 'beside', 'nordic', 'east-european', 'dinaric', 'western type', 'grave drawback', 'germans', 'strong herd instinct', 'critical times', 'such occasions', 'small differences disappear', 'word hyper-individualism', 'racial elements', 'historical development', 'german people', 'herd instinct', 'reich', 'world history', 'pacifists hope', 'olive branches', 'old women', 'triumphant sword']
#     Paragraph common words: [('element', 7), ('german', 5), ('type', 4), ('side', 4), ('herd', 4)]
#
# Paragraph 91
#     Paragraph topics: [(0, '0.045*"based" + 0.045*"capital"'), (1, '0.074*"german" + 0.074*"people"'), (2, '0.045*"city" + 0.045*"many"')]
#     Paragraph sentiment: 0.19714285714285712
#     Paragraph nouns: ['untold misery', 'german', 'residential capital cities', 'german people']
#     Paragraph common words: [('people', 2), ('german', 2), ('fact', 1), ('national', 1), ('based', 1)]
#
# Paragraph 92
#     Paragraph topics: [(0, '0.040*"racial" + 0.040*"hand"'), (1, '0.024*"kept" + 0.024*"thus"'), (2, '0.024*"today" + 0.024*"lack"')]
#     Paragraph sentiment: 0.03392857142857143
#     Paragraph nouns: ['inner unity', 'present misfortunes', 'racial elements', 'national body', 'racial quality']
#     Paragraph common words: [('may', 2), ('hand', 2), ('racial', 2), ('even', 1), ('today', 1)]
#
# Paragraph 93
#     Paragraph topics: [(0, '0.011*"perfection" + 0.011*"chosen"'), (1, '0.038*"racial" + 0.038*"would"'), (2, '0.011*"capable" + 0.011*"creating"')]
#     Paragraph sentiment: 0.09373015873015873
#     Paragraph nouns: ['complete assimilation', 'racial elements', 'national organism', 'racial mixture', 'original elements', 'all-round assimilation', 'large groups', 'nordic', 'national organization', 'valuable treasure', 'dark period', 'absolute ignorance', 'racial laws', 'clear appreciation', 'various fundamental racial characteristics', 'complete assimilation', 'various elements', 'external power', 'human aims', 'general mixture', 'racial amalgamation']
#     Paragraph common words: [('racial', 5), ('would', 5), ('assimilation', 3), ('element', 3), ('national', 3)]
#
# Paragraph 94
#     Paragraph topics: [(0, '0.083*"utilized" + 0.083*"friendly"'), (1, '0.083*"assistance" + 0.083*"destiny"'), (2, '0.083*"utilized" + 0.083*"friendly"')]
#     Paragraph sentiment: 0.3037878787878788
#     Paragraph nouns: ['destiny', 'new knowledge']
#     Paragraph common words: [('prevented', 1), ('friendly', 1), ('destiny', 1), ('without', 1), ('assistance', 1)]
#
# Paragraph 95
# ...
#     Paragraph sentiment: 0.15833333333333333
#     Paragraph nouns: ['france', "'s occupation", 'ruhr', 'military implements', 'spiritual weapons', 'will power', 'national strength']
#     Paragraph common words: [('power', 2), ('anyone', 1), ('spring', 1), ('1923', 1), ('wanted', 1)]
#
# Paragraph 1136
#     Paragraph topics: [(0, '0.040*"1923" + 0.040*"blood"'), (1, '0.068*"marxist" + 0.039*"proceed"'), (2, '0.040*"1914" + 0.040*"1915"')]
#     Paragraph sentiment: 0.6
#     Paragraph nouns: ['marxist', 'marxist']
#     Paragraph common words: [('marxist', 2), ('1918', 1), ('paid', 1), ('blood', 1), ('fact', 1)]
#
# Paragraph 1137
#     Paragraph topics: [(0, '0.006*"five" + 0.006*"all"'), (1, '0.033*"german" + 0.019*"marxist"'), (2, '0.006*"arrive" + 0.006*"profiteer"')]
#     Paragraph sentiment: 0.060833333333333336
#     Paragraph nouns: ['real resistance', 'france', 'utter nonsense', 'german resistance', 'bourgeois minds', 'incredible opinion', 'marxism', 'dead underfoot', 'various seats', 'national conscience', 'insane idea', 'german freedom', 'hyena abandons carrion', 'marxist', 'abandon treason', "n't annoy", 'germany', 'german workers', 'marxists', 'innermost convictions', 'marxists', 'germany', 'german people', 'marxist', 'bottommost depths', 'exact proportion', 'german worker', 'german soldier', 'marxist', 'hebrew', 'poison gas', 'german workers', 'th sacrifice', 'germans', "bourgeois 'statesmanship", 'subject millions', 'bloody end', 'national treasure', 'bourgeois world', 'fate', 'whole nation']
#     Paragraph common words: [('german', 9), ('war', 5), ('marxist', 5), ('million', 4), ('would', 4)]
#
# Paragraph 1138
#     Paragraph topics: [(0, '0.014*"order" + 0.014*"resolved"'), (1, '0.032*"national" + 0.022*"first"'), (2, '0.014*"street" + 0.014*"basic"')]
#     Paragraph sentiment: 0.13137755102040816
#     Paragraph nouns: ['regardless', 'marxist', 'national body', 'national government', 'marxism', 'free road', 'street corner', 'national government', 'marxism', 'pure madness']
#     Paragraph common words: [('national', 3), ('regardless', 2), ('type', 2), ('resistance', 2), ('first', 2)]
#
# Paragraph 1139
#     Paragraph topics: [(0, '0.017*"required" + 0.017*"steeled"'), (1, '0.017*"kid" + 0.017*"active"'), (2, '0.029*"life" + 0.029*"people"')]
#     Paragraph sentiment: 0.09180555555555557
#     Paragraph nouns: ['real world-historical import', 'privy councilor', 'old minister', 'eternal laws', 'civil wars', 'healthy people', 'heaven', 'kid gloves', 'brutal thrust', 'active resistance']
#     Paragraph common words: [('life', 2), ('struggle', 2), ('people', 2), ('reckoning', 1), ('real', 1)]
#
# Paragraph 1140
#     Paragraph topics: [(0, '0.037*"time" + 0.037*"give"'), (1, '0.022*"often" + 0.022*"talked"'), (2, '0.022*"1918" + 0.022*"often"')]
#     Paragraph sentiment: 0.15000000000000002
#     Paragraph nouns: ['throat hoarse', 'so-called national circles', 'free rein', 'pate', 'marxism', 'deaf ears']
#     Paragraph common words: [('time', 2), ('give', 2), ('often', 1), ('talked', 1), ('throat', 1)]
#
# Paragraph 1141
#     Paragraph topics: [(0, '0.029*"destined" + 0.029*"for"'), (1, '0.049*"mission" + 0.028*"annihilate"'), (2, '0.029*"heart" + 0.029*"end"')]
#     Paragraph sentiment: 0.01666666666666667
#     Paragraph nouns: ['german bourgeoisie', 'marxists', 'serious desire', 'grave concern', 'funeral feast']
#     Paragraph common words: [('mission', 2), ('realized', 1), ('innermostsoul', 1), ('german', 1), ('bourgeoisie', 1)]
#
# Paragraph 1142
#     Paragraph topics: [(0, '0.028*"love" + 0.028*"conceived"'), (1, '0.047*"great" + 0.047*"italy"'), (2, '0.028*"earth" + 0.028*"pact"')]
#     Paragraph sentiment: 0.20714285714285713
#     Paragraph nouns: ['profoundest admiration', 'great man', 'alps', 'italy', 'mussolini', 'great men', 'italy', 'marxists']
#     Paragraph common words: [('great', 2), ('italy', 2), ('periodi', 1), ('openly', 1), ('admiti', 1)]
#
# Paragraph 1143
#     Paragraph topics: [(0, '0.031*"barely" + 0.031*"comparison"'), (1, '0.031*"century" + 0.031*"barely"'), (2, '0.031*"arrogance" + 0.031*"call"')]
#     Paragraph sentiment: -0.2733333333333333
#     Paragraph nouns: ['german would-be statesmen', 'boorish arrogance', 'bismarck']
#     Paragraph common words: [('miserable', 1), ('dwarfish', 1), ('german', 1), ('wouldbe', 1), ('statesman', 1)]
#
# Paragraph 1144
#     Paragraph topics: [(0, '0.014*"foe" + 0.014*"staged"'), (1, '0.042*"enemy" + 0.023*"would"'), (2, '0.014*"foreign" + 0.014*"graz"')]
#     Paragraph sentiment: 0.009523809523809521
#     Paragraph nouns: ['marxists', 'active resistance', 'france', 'own ranks', 'sheer idiocy', 'nationalistic element', 'germany', 'foreign enemies', 'god', 'defeat grazes', 'internal enemies', 'final victor']
#     Paragraph common words: [('enemy', 4), ('resistance', 2), ('would', 2), ('people', 2), ('view', 1)]
#
# Paragraph 1145
#     Paragraph topics: [(0, '0.019*"let" + 0.019*"saved"'), (1, '0.031*"enemy" + 0.031*"success"'), (2, '0.019*"mention" + 0.019*"defeated"')]
#     Paragraph sentiment: 0.14791666666666667
#     Paragraph nouns: ['february', 'military success', 'france', 'german action', 'ruhr', 'marxism', 'germany', 'mortal enemies', 'whole world', 'marxism', 'germany', 'fetters wig', 'own vices', 'own camp']
#     Paragraph common words: [('could', 2), ('success', 2), ('marxism', 2), ('would', 2), ('germany', 2)]
#
# Paragraph 1146
#     Paragraph topics: [(0, '0.059*"courage" + 0.059*"course"'), (1, '0.059*"course" + 0.059*"courage"'), (2, '0.099*"could" + 0.056*"letting"')]
#     Paragraph sentiment: 0.19999999999999998
#     Paragraph nouns: ['german state', 'heroic deed', 'things slide']
#     Paragraph common words: [('could', 2), ('since', 1), ('leader', 1), ('german', 1), ('state', 1)]
#
# Paragraph 1147
#     Paragraph topics: [(0, '0.026*"business" + 0.026*"kind"'), (1, '0.043*"really" + 0.043*"great"'), (2, '0.026*"curse" + 0.026*"sent"')]
#     Paragraph sentiment: 0.2652014652014652
#     Paragraph nouns: ['great hour', 'heaven', 'german people', 'great man', 'herr', 'cuno', 'political hack', 'certain definite jobs', 'germany', 'economic enterprise']
#     Paragraph common words: [('great', 2), ('really', 2), ('politics', 2), ('hour', 1), ('heaven', 1)]
#
# Paragraph 1148
#     Paragraph topics: [(0, '0.078*"ruhr" + 0.060*"coal"'), (1, '0.029*"address" + 0.029*"proved"'), (2, '0.029*"enterprise" + 0.029*"account"')]
#     Paragraph sentiment: 0.20476190476190476
#     Paragraph nouns: ['ruhr', 'ruhr', 'france', 'ruhr', 'herr cuno', 'herr cuno', 'ruhr', 'stuttgart', 'blissful admiration']
#     Paragraph common words: [('ruhr', 4), ('coal', 3), ('france', 2), ('occupied', 2), ('herr', 2)]
#
# Paragraph 1149
#     Paragraph topics: [(0, '0.010*"timethere" + 0.010*"hand"'), (1, '0.028*"marxist" + 0.028*"national"'), (2, '0.010*"nation" + 0.010*"expense"')]
#     Paragraph sentiment: 0.1475
#     Paragraph nouns: ['marxists', 'bourgeois statesman', 'marxist', 'germans', 'political party cheeses', 'brilliant slogan', 'marxism', 'national swindler', 'teutonic', 'german phrases', 'friendly hand', 'international traitor', 'utmost alacrity', 'cuno', 'marxist', 'marxist', 'cuno', "'s money", 'cuno', 'national windbags', 'anti-national scoundrels', 'international swindlers', 'state funds', 'supreme mission', 'national economy', 'immortal idea', 'general strike', 'full enthusiasm']
#     Paragraph common words: [('marxist', 4), ('national', 4), ('strike', 3), ('united', 3), ('front', 3)]
#
# Paragraph 1150
#     Paragraph topics: [(0, '0.039*"front" + 0.039*"made"'), (1, '0.024*"cannot" + 0.024*"freed"'), (2, '0.024*"cannot" + 0.024*"one"')]
#     Paragraph sentiment: 0.15555555555555556
#     Paragraph nouns: ['berr cuno', 'general strike', 'peoples']
#     Paragraph common words: [('made', 2), ('free', 2), ('united', 2), ('front', 2), ('generally', 1)]
#
# Paragraph 1151
#     Paragraph topics: [(0, '0.033*"ignorant" + 0.033*"foundation"'), (1, '0.033*"billion" + 0.033*"helped"'), (2, '0.079*"could" + 0.032*"frightened"')]
#     Paragraph sentiment: 0.04629629629629631
#     Paragraph nouns: ['so-called passive resistance', 'such ridiculous means', 'national currency']
#     Paragraph common words: [('could', 3), ('sure', 1), ('socalled', 1), ('passive', 1), ('resistance', 1)]
#
# Paragraph 1152
#     Paragraph topics: [(0, '0.007*"recalcitrant" + 0.007*"authority"'), (1, '0.007*"abandon" + 0.007*"certainty"'), (2, '0.025*"resistance" + 0.020*"struggle"')]
#     Paragraph sentiment: -0.05177045177045177
#     Paragraph nouns: ['ruhr', 'certain sense', 'inner relief', 'such methods', 'recalcitrant civilian population', 'serious menace', 'occupation authorities', 'belgian franc-tireur bands', 'civilian population', 'german armies', 'serious damage', 'passive resistance', 'ruhr', "child 's", 'cruel end', 'whole childish mischief', 'ultimate question', 'passive resistance ends', "adversary 's nerves", 'brutal strong-arm methods', 'bloodiest persecutions', 'active resistance', 'mace', 'hence', 'so-called passive resistance', 'inner meaning', 'open struggle', 'undercover guerrilla warfare', 'such struggle', 'heavy attack', 'practical purposes', 'probable death', 'rob', 'possible liberation']
#     Paragraph common words: [('resistance', 5), ('struggle', 4), ('soon', 3), ('passive', 3), ('french', 2)]
#
# Paragraph 1153
#     Paragraph topics: [(0, '0.021*"success" + 0.021*"thorny"'), (1, '0.035*"could" + 0.035*"would"'), (2, '0.021*"always" + 0.021*"frenchman"')]
#     Paragraph sentiment: 0.14696969696969697
#     Paragraph nouns: ['passive resistance', 'ruhr', 'ultimate consequences', 'active front', 'westphalians', 'frenchmen', 'courageous men']
#     Paragraph common words: [('could', 2), ('would', 2), ('therefore', 1), ('passive', 1), ('resistance', 1)]
#
# Paragraph 1154
#     Paragraph topics: [(0, '0.069*"national" + 0.021*"agreeable"'), (1, '0.022*"attitude" + 0.022*"forced"'), (2, '0.022*"unable" + 0.022*"attacked"')]
#     Paragraph sentiment: 0.010437925170068033
#     Paragraph nouns: ['classical case', 'socialists', 'sharpest position', 'so-called national slogan', 'whole national attitude', 'outward sham', 'agreeable thrill', 'national airs', 'ridiculous phenomenon']
#     Paragraph common words: [('national', 4), ('classical', 1), ('case', 1), ('forced', 1), ('u', 1)]
#
# Paragraph 1155
#     Paragraph topics: [(0, '0.026*"filled" + 0.026*"hyena"'), (1, '0.026*"ingloriously" + 0.026*"passing"'), (2, '0.044*"one" + 0.025*"passive"')]
#     Paragraph sentiment: 0.21333333333333337
#     Paragraph nouns: ['cuno', "'s funds", 'passive resistance', 'active attack', 'red hyenas', 'national sheep herd', 'quietly', 'herr cuno', 'germany', 'great hope']
#     Paragraph common words: [('one', 2), ('soon', 1), ('union', 1), ('filled', 1), ('treasury', 1)]
#
# Paragraph 1156
#     Paragraph topics: [(0, '0.025*"hoped" + 0.025*"officer"'), (1, '0.025*"secret" + 0.025*"german"'), (2, '0.042*"least" + 0.042*"many"')]
#     Paragraph sentiment: -0.03492063492063493
#     Paragraph nouns: ['down', 'late midsummer', 'disgraceful development', 'french assault', 'turning point', 'german history', 'reichswehr', 'innumerable young people']
#     Paragraph common words: [('many', 2), ('least', 2), ('late', 1), ('midsummer', 1), ('officer', 1)]
#
# Paragraph 1157
#     Paragraph topics: [(0, '0.025*"radical" + 0.025*"conviction"'), (1, '0.043*"disgraceful" + 0.025*"could"'), (2, '0.025*"unfortunate" + 0.025*"billion"')]
#     Paragraph sentiment: -0.0111111111111111
#     Paragraph nouns: ['disgraceful collapse', 'disgraceful capitulation', 'germans-who', 'reich', "'s leaders seriously- indignation", 'unfortunate people', 'radical elimination', 'whole ruling system', 'germany']
#     Paragraph common words: [('disgraceful', 2), ('collapse', 1), ('occurred', 1), ('crushing', 1), ('capitulation', 1)]
#
# Paragraph 1158
#     Paragraph topics: [(0, '0.027*"hand" + 0.027*"hatred"'), (1, '0.017*"sacrifice" + 0.017*"mocked"'), (2, '0.017*"loyalty" + 0.017*"final"')]
#     Paragraph sentiment: 0.11236263736263738
#     Paragraph nouns: ['never', 'time riper', 'slow starvation', 'faith underfoot', 'truest sons', 'final sentence', 'great trial']
#     Paragraph common words: [('never', 2), ('hand', 2), ('people', 2), ('right', 2), ('million', 2)]
#
# Paragraph 1159
#     Paragraph topics: [(0, '0.040*"acquitting" + 0.040*"convict"'), (1, '0.066*"higher" + 0.066*"u"'), (2, '0.040*"the" + 0.040*"may"')]
#     Paragraph sentiment: 0.19642857142857142
#     Paragraph nouns: ["'the judges", 'history']
#     Paragraph common words: [('u', 2), ('higher', 2), ('the', 1), ('judge', 1), ('state', 1)]
#
# Paragraph 1160
#     Paragraph topics: [(0, '0.048*"fatherland" + 0.048*"judgment"'), (1, '0.048*"people" + 0.048*"seat"'), (2, '0.048*"amid" + 0.048*"call"')]
#     Paragraph sentiment: 0.3
#     Paragraph nouns: ['judgment seat', 'trample justice', 'law underfoot', 'own ego']
#     Paragraph common words: [('call', 1), ('judgment', 1), ('seat', 1), ('today', 1), ('possession', 1)]
#
# Paragraph 1161
#     Paragraph topics: [(0, '0.028*"scarcely" + 0.028*"promise"'), (1, '0.047*"useless" + 0.047*"shall"'), (2, '0.028*"led" + 0.028*"road"')]
#     Paragraph sentiment: -0.14444444444444446
#     Paragraph nouns: ['november', 'reopen wounds', 'common road']
#     Paragraph common words: [('shall', 2), ('useless', 2), ('place', 1), ('continue', 1), ('account', 1)]
#
# Paragraph 1162
#     Paragraph topics: [(0, '0.027*"death" + 0.027*"future"'), (1, '0.042*"common" + 0.042*"day"'), (2, '0.027*"death" + 0.027*"true"')]
#     Paragraph sentiment: 0.15624999999999997
#     Paragraph nouns: ['great common misfortune', 'germans', 'common front', 'bitter road', 'german people']
#     Paragraph common words: [('great', 2), ('common', 2), ('day', 2), ('front', 2), ('german', 2)]
#
# Paragraph 1163
#     Paragraph topics: [(0, '0.023*"dedicated" + 0.023*"his"'), (1, '0.037*"volume" + 0.037*"best"'), (2, '0.023*"his" + 0.023*"carried"')]
#     Paragraph sentiment: 0.26785714285714285
#     Paragraph nouns: ['clearest consciousness', 'final consequence']
#     Paragraph common words: [('volume', 2), ('hero', 2), ('duty', 2), ('best', 2), ('wish', 1)]
#
# Paragraph 1164
#     Paragraph topics: [(0, '0.065*"november" + 0.037*"firmer"'), (1, '0.038*"socialist" + 0.038*"reich"'), (2, '0.038*"german" + 0.038*"ever"')]
#     Paragraph sentiment: 0.15000000000000002
#     Paragraph nouns: ['on november', 'reich', 'november']
#     Paragraph common words: [('november', 2), ('9', 1), ('1923', 1), ('fourth', 1), ('year', 1)]
#
# Paragraph 1165
#     Paragraph topics: [(0, '0.048*"caused" + 0.048*"vilification"'), (1, '0.048*"vilification" + 0.048*"persecution"'), (2, '0.048*"ever" + 0.048*"harm"')]
#     Paragraph sentiment: -0.25
#     Paragraph nouns: ['individual leaders']
#     Paragraph common words: [('persecution', 1), ('movement', 1), ('individual', 1), ('leader', 1), ('vilification', 1)]
#
# Paragraph 1166
#     Paragraph topics: [(0, '0.049*"struggle" + 0.028*"parliamentary"'), (1, '0.029*"race" + 0.029*"victorious"'), (2, '0.029*"world" + 0.029*"led"')]
#     Paragraph sentiment: 0.2928571428571428
#     Paragraph nouns: ['present parliamentary corruption', 'profoundest essence', 'purest embodiment', 'mathematical certainty', 'germany', 'rightful position']
#     Paragraph common words: [('struggle', 2), ('if', 1), ('world', 1), ('present', 1), ('parliamentary', 1)]
#
# Paragraph 1167
#     Paragraph topics: [(0, '0.127*"racial" + 0.073*"become"'), (1, '0.077*"age" + 0.077*"become"'), (2, '0.077*"must" + 0.077*"age"')]
#     Paragraph sentiment: 1.0
#     Paragraph nouns: ['racial elements']
#     Paragraph common words: [('racial', 2), ('state', 1), ('age', 1), ('poisoning', 1), ('dedicates', 1)]
#
# Paragraph 1168
#     Paragraph topics: [(0, '0.077*"adherent" + 0.077*"anxious"'), (1, '0.077*"forget" + 0.077*"anxious"'), (2, '0.077*"sacrifice" + 0.077*"magnitude"')]
#     Paragraph sentiment: -0.125
#     Paragraph nouns: ['may', 'anxious comparison', 'possible results']
#     Paragraph common words: [('may', 1), ('adherent', 1), ('movement', 1), ('never', 1), ('forget', 1)]
#
# Wall time: 11min 13s
